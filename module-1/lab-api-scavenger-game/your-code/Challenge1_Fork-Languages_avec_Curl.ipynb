# %%
import pandas as pd
from pandas.io.json import json_normalize
import json
import os

# %%
data_forks = pd.read_json('forks.json', orient='records')

# %%
data_forks
# Out:
#                                           archive_url  archived  \
# 0   https://api.github.com/repos/Tiviia/data-labs/...     False
# 1   https://api.github.com/repos/carlarsmendes/dat...     False
# 2   https://api.github.com/repos/amartinezm90/data...     False
# 3   https://api.github.com/repos/pedro-munoz/data-...     False
# 4   https://api.github.com/repos/uaqro/data-labs/{...     False
# 5   https://api.github.com/repos/eduarde1/data-lab...     False
# 6   https://api.github.com/repos/Weslley-MS/data-l...     False
# 7   https://api.github.com/repos/jotapescabora/dat...     False
# 8   https://api.github.com/repos/GabrieleGoncalves...     False
# 9   https://api.github.com/repos/Guiaugustosilva/d...     False
# 10  https://api.github.com/repos/lenon51/data-labs...     False
# 11  https://api.github.com/repos/GBPadova/data-lab...     False
# 12  https://api.github.com/repos/isafloriano/data-...     False
# 13  https://api.github.com/repos/isabelalemos/data...     False
# ...

# %%
data_forks.columns
# Out:
# Index(['archive_url', 'archived', 'assignees_url', 'blobs_url', 'branches_url',
#        'clone_url', 'collaborators_url', 'comments_url', 'commits_url',
#        'compare_url', 'contents_url', 'contributors_url', 'created_at',
#        'default_branch', 'deployments_url', 'description', 'disabled',
#        'downloads_url', 'events_url', 'fork', 'forks', 'forks_count',
#        'forks_url', 'full_name', 'git_commits_url', 'git_refs_url',
#        'git_tags_url', 'git_url', 'has_downloads', 'has_issues', 'has_pages',
#        'has_projects', 'has_wiki', 'homepage', 'hooks_url', 'html_url', 'id',
#        'issue_comment_url', 'issue_events_url', 'issues_url', 'keys_url',
#        'labels_url', 'language', 'languages_url', 'license', 'merges_url',
#        'milestones_url', 'mirror_url', 'name', 'node_id', 'notifications_url',
#        'open_issues', 'open_issues_count', 'owner', 'permissions', 'private',
#        'pulls_url', 'pushed_at', 'releases_url', 'size', 'ssh_url',
# ...

# %%
language=[]
[language.append(f) for f in data_forks['language'] if f not in language]
language
# Out:
# ['Jupyter Notebook']

# %%
data_commit = pd.read_json('commit.json', orient='records')
data_commit
# Out:
#                                                author  \
# 0   {'login': 'kbartonhenry', 'id': 22545329, 'nod...
# 1   {'login': 'kbartonhenry', 'id': 22545329, 'nod...
# 2   {'login': 'kbartonhenry', 'id': 22545329, 'nod...
# 3   {'login': 'kbartonhenry', 'id': 22545329, 'nod...
# 4   {'login': 'kbartonhenry', 'id': 22545329, 'nod...
# 5   {'login': 'kbartonhenry', 'id': 22545329, 'nod...
# 6   {'login': 'kbartonhenry', 'id': 22545329, 'nod...
# 7   {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 8   {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 9   {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 10  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 11  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 12  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 13  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 14  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 15  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# ...

# %%
data_commit['commit'].value_counts()
# Out:
# {'author': {'name': 'himanshu aggarwal', 'email': 'himanshuaggarwal@himanshus-macbook-pro.local', 'date': '2019-06-01T03:46:49Z'}, 'committer': {'name': 'himanshu aggarwal', 'email': 'himanshuaggarwal@himanshus-macbook-pro.local', 'date': '2019-06-01T03:46:49Z'}, 'message': 'Business Intelligence with Tableau and Python Added', 'tree': {'sha': '742ac6717106ac57c6f496445b5a78f0e856dd79', 'url': 'https://api.github.com/repos/ironhack-labs/data-labs/git/trees/742ac6717106ac57c6f496445b5a78f0e856dd79'}, 'url': 'https://api.github.com/repos/ironhack-labs/data-labs/git/commits/3fb5db573313c3fe3ff3419ae8cf62674e2a6738', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None}}                                                                                                                                                                                                                                                                       
# ...

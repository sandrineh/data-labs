# %%
# your code here
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
h = open('lab_scavenger.txt').read()
headers=h
url='https://api.github.com/repos/ironhack-labs/data-labs/forks'

##### Challenge 1: Forks
response = requests.get(url,headers)

results = response.json()
results
# Out:
# [{'id': 197480497,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxOTc0ODA0OTc=',
#   'name': 'data-labs',
#   'full_name': 'moap04/data-labs',
#   'private': False,
#   'owner': {'login': 'moap04',
#    'id': 27080898,
#    'node_id': 'MDQ6VXNlcjI3MDgwODk4',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/27080898?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/moap04',
#    'html_url': 'https://github.com/moap04',
#    'followers_url': 'https://api.github.com/users/moap04/followers',
#    'following_url': 'https://api.github.com/users/moap04/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/moap04/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/moap04/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/moap04/subscriptions',
#    'organizations_url': 'https://api.github.com/users/moap04/orgs',
#    'repos_url': 'https://api.github.com/users/moap04/repos',
# ...

# %%
"""Link: <https://api.github.com/repositories/147683540/forks?page=2>; rel="next",
<https://api.github.com/repositories/147683540/forks?page=3>; rel="last"
"""
df_forks = pd.DataFrame()
total_pages=3
for i in range(total_pages):
    #k=84*i
    url=f'https://api.github.com/repos/ironhack-labs/data-labs/forks?page={i}'
    forks = requests.get(url,headers)
    j_forks = forks.json()
    df = json_normalize(j_forks)
    df = df.set_index('owner.login')
    df_forks = df_forks.append(df)
    #flattened_data1 = json_normalize(flattened_data.articles[0])
    #flattened_data1=flattened_data1.set_index('sku')

df_forks
# Out:
#                                                                         archive_url  \
# owner.login
# moap04                            https://api.github.com/repos/moap04/data-labs/...
# Tiviia                            https://api.github.com/repos/Tiviia/data-labs/...
# carlarsmendes                     https://api.github.com/repos/carlarsmendes/dat...
# amartinezm90                      https://api.github.com/repos/amartinezm90/data...
# pedro-munoz                       https://api.github.com/repos/pedro-munoz/data-...
# uaqro                             https://api.github.com/repos/uaqro/data-labs/{...
# eduarde1                          https://api.github.com/repos/eduarde1/data-lab...
# Weslley-MS                        https://api.github.com/repos/Weslley-MS/data-l...
# jotapescabora                     https://api.github.com/repos/jotapescabora/dat...
# GabrieleGoncalves                 https://api.github.com/repos/GabrieleGoncalves...
# ...

# %%
df_forks.columns
# Out:
# Index(['archive_url', 'archived', 'assignees_url', 'blobs_url', 'branches_url',
#        'clone_url', 'collaborators_url', 'comments_url', 'commits_url',
#        'compare_url', 'contents_url', 'contributors_url', 'created_at',
#        'default_branch', 'deployments_url', 'description', 'disabled',
#        'downloads_url', 'events_url', 'fork', 'forks', 'forks_count',
#        'forks_url', 'full_name', 'git_commits_url', 'git_refs_url',
#        'git_tags_url', 'git_url', 'has_downloads', 'has_issues', 'has_pages',
#        'has_projects', 'has_wiki', 'homepage', 'hooks_url', 'html_url', 'id',
#        'issue_comment_url', 'issue_events_url', 'issues_url', 'keys_url',
#        'labels_url', 'language', 'languages_url', 'license.key',
#        'license.name', 'license.node_id', 'license.spdx_id', 'license.url',
#        'merges_url', 'milestones_url', 'mirror_url', 'name', 'node_id',
#        'notifications_url', 'open_issues', 'open_issues_count',
# ...

# %%
df_forks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, moap04 to jbe1992
# Data columns (total 93 columns):
# archive_url                  90 non-null object
# archived                     90 non-null bool
# assignees_url                90 non-null object
# blobs_url                    90 non-null object
# branches_url                 90 non-null object
# clone_url                    90 non-null object
# collaborators_url            90 non-null object
# comments_url                 90 non-null object
# commits_url                  90 non-null object
# compare_url                  90 non-null object
# contents_url                 90 non-null object
# contributors_url             90 non-null object
# created_at                   90 non-null object
# default_branch               90 non-null object
# deployments_url              90 non-null object
# description                  0 non-null object
# disabled                     90 non-null bool
# ...

# %%
language=[]
[language.append(f) for f in df_forks['language'] if f not in language]
language
# Out:
# ['Jupyter Notebook']

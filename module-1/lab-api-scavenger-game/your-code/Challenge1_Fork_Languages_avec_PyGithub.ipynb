# %%
from github import Github
import pandas as pd
import json

# %%
# %load tok.py
tok = "9723d74078275412b4bb042b71738f26439aa0ef"

# %%
g = Github(tok)
repo = g.get_repo("ironhack-labs/data-labs")


#Then play with your Github objects:
for rep in g.get_user("ironhack-labs").get_repos("data-labs"):
    print(rep.name)
# Out:
# client-ironphones
# code-along-uber-for-laundry
# data-labs
# data-prework-labs
# file-upload-example-server
# guided-game-2048
# Hackathon-plate
# katas-collection
# lab-advance-querying-mongo
# lab-ajax-crud-characters
# lab-angular-access-control
# lab-angular-cinema-billboard
# lab-angular-data-binding
# lab-angular-forum
# lab-angular-introduction
# lab-angular-ironcontacts
# lab-angular-recipes
# lab-angular-secrets
# lab-angular-simple-journal
# lab-authentication-with-passport
# lab-beach-finder
# lab-bootstrap-cloning-github
# lab-bootstrap-cloning-revera
# lab-bootstrap-cloning-south-summit
# lab-bulma-components
# lab-canvas-flappybirds
# lab-canvas-hangman
# lab-canvas-race-car
# lab-coffee-and-books
# lab-css-flexbox-slack
# lab-css-instagram-clone
# lab-css-recipes-clone
# lab-css-responsive-cloning
# lab-css-spotify-clone
# lab-dom-ironhack-cart
# lab-dom-pizza-builder
# lab-es6-algorithms
# lab-es6-javascript-koans
# lab-express-basic-auth
# lab-express-basic-site
# ...

# %%
fork=list(repo.get_forks())

# %%
df_fork=pd.DataFrame(fork)
df_fork.rename(columns={0:'FORK'},inplace=True)

df_fork
# Out:
#                                                  FORK
# 0     Repository(full_name="carlarsmendes/data-labs")
# 1      Repository(full_name="amartinezm90/data-labs")
# 2       Repository(full_name="pedro-munoz/data-labs")
# 3             Repository(full_name="uaqro/data-labs")
# 4          Repository(full_name="eduarde1/data-labs")
# 5        Repository(full_name="Weslley-MS/data-labs")
# 6     Repository(full_name="jotapescabora/data-labs")
# 7   Repository(full_name="GabrieleGoncalves/data-l...
# 8   Repository(full_name="Guiaugustosilva/data-labs")
# 9           Repository(full_name="lenon51/data-labs")
# 10         Repository(full_name="GBPadova/data-labs")
# 11      Repository(full_name="isafloriano/data-labs")
# 12     Repository(full_name="isabelalemos/data-labs")
# 13     Repository(full_name="katiaiwasaki/data-labs")
# 14  Repository(full_name="vanessaboaventura/data-l...
# 15          Repository(full_name="vmcarva/data-labs")
# ...

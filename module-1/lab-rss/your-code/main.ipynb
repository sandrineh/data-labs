# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
oreilly = feedparser.parse(url)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
oreilly.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
oreilly.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'id', 'guidislink', 'link', 'updated', 'updated_parsed', 'subtitle', 'subtitle_detail', 'links', 'authors', 'author_detail', 'author', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
oreilly.feed.title,oreilly.feed.subtitle,oreilly.feed.author,oreilly.feed.link
# Out:
# ("All - O'Reilly Media",
#  'All of our Ideas and Learning material from all of our topics.',
#  "O'Reilly Media",
#  'https://www.oreilly.com')

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
print(len(oreilly.entries))
# Out:
# 60

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
oreilly.entries[0].keys()
# Out:
# dict_keys(['title', 'title_detail', 'updated', 'updated_parsed', 'id', 'guidislink', 'link', 'content', 'summary', 'links', 'authors', 'author_detail', 'author', 'feedburner_origlink'])

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles = [oreilly.entries[i].title for i in range(len(oreilly.entries))]
titles
# Out:
# ['Four short links: 22 July 2019',
#  'Four short links: 19 July 2019',
#  'The war for the soul of open source',
#  "O'Reilly Open Source and Frank Willison Awards",
#  'O’Reilly Radar: Open source technology trends—What our users tell us',
#  'Ask not what Brands™ can do for you',
#  'Managing machines',
#  'Acquiring and sharing high-quality data',
#  'Four short links: 18 July 2019',
#  'The role of open source in mitigating natural disasters',
#  "Highlights from the O'Reilly Open Source Software Conference in Portland 2019",
#  'Better living through software',
#  'Why Amazon cares about open source',
#  'Built to last: Building and growing open source communities',
#  'The next age of open innovation',
#  'Four short links: 17 July 2019',
#  'Four short links: 16 July 2019',
#  'Managing machine learning in the enterprise: Lessons from banking and health care',
#  'Four short links: 15 July 2019',
#  'Four short links: 12 July 2019',
#  'Four short links: 11 July 2019',
#  'Four short links: 10 July 2019',
#  'Four short links: 9 July 2019',
#  'The circle of fairness',
#  "Highlights from the O'Reilly Artificial Intelligence Conference in Beijing 2019",
#  'The future of machine learning is tiny',
#  'Toward learned algorithms, data structures, and systems',
#  'Top AI breakthroughs you need to know',
#  'Data orchestration for AI, big data, and cloud',
#  'AI and retail',
#  'The future of hiring and the talent market with AI',
#  'AI and systems at RISELab',
#  'Designing computer hardware for artificial intelligence',
#  'Four short links: 8 July 2019',
#  'Four short links: 5 July 2019',
#  'Four short links: 4 July 2019',
#  'Tools for machine learning development',
#  'New live online training courses',
#  'Four short links: 3 July 2019',
#  'Four short links: 2 July 2019',
#  'Four short links: 1 July 2019',
#  'RISELab’s AutoPandas hints at automation tech that will change the nature of software development',
#  'Four short links: 28 June 2019',
#  'One simple chart: Who is interested in Spark NLP?',
#  'Four short links: 27 June 2019',
#  'Four short links: 26 June 2019',
#  'AI and machine learning will require retraining your entire organization',
#  'Four short links: 25 June 2019',
#  'Four short links: 24 June 2019',
#  'Four short links: 21 June 2019',
#  'Four short links: 20 June 2019',
#  'Enabling end-to-end machine learning pipelines in real-world applications',
#  'Four short links: 19 June 2019',
#  'What are model governance and model operations?',
#  'Four short links: 18 June 2019',
#  'The quest for high-quality data',
#  'Four short links: 17 June 2019',
#  'Prioritizing technical debt as if time and money mattered',
#  'From the trenches with Rebecca Parsons',
#  'Choices of scale']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
calc=0
for t in titles:
    if "Four short links" in t:
        calc = calc+1
calc
pourcentage = (calc /len(oreilly.entries))*100
pourcentage
# Out:
# 43.333333333333336

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df = pd.DataFrame(oreilly.entries)
df
# Out:
#                                    author  \
# 0                          Nat Torkington
# 1                          Nat Torkington
# 2                              Adam Jacob
# 3                                     NaN
# 4                          Roger Magoulas
# 5                             VM Brasseur
# 6                          Pete Skomoroch
# 7                              Ben Lorica
# 8                          Nat Torkington
# 9                  Pedro Cruz, Brad Topol
# 10                             Mac Slocum
# 11                           Tiffani Bell
# 12                             Arun Gupta
# 13                           Kay Williams
# 14                        Alison McCauley
# 15                         Nat Torkington
# 16                         Nat Torkington
# 17  Ben Lorica, Harish Doddi, David Talby
# 18                         Nat Torkington
# 19                         Nat Torkington
# 20                         Nat Torkington
# 21                         Nat Torkington
# 22                         Nat Torkington
# 23                          Mike Loukides
# 24                              Jenn Webb
# 25                            Pete Warden
# 26                             Tim Kraska
# 27                       Abigail Hing Wen
# 28                             Haoyuan Li
# 29                            Mikio Braun
# 30                            Maria Zhang
# 31                             Ion Stoica
# 32                          Michael James
# 33                         Nat Torkington
# 34                         Nat Torkington
# 35                         Nat Torkington
# 36                              Jenn Webb
# 37                                    NaN
# 38                         Nat Torkington
# 39                         Nat Torkington
# 40                         Nat Torkington
# 41                             Ben Lorica
# 42                         Nat Torkington
# 43                             Ben Lorica
# 44                         Nat Torkington
# 45                         Nat Torkington
# 46                             Ben Lorica
# 47                         Nat Torkington
# 48                         Nat Torkington
# 49                         Nat Torkington
# 50                         Nat Torkington
# 51                             Ben Lorica
# 52                         Nat Torkington
# 53  Ben Lorica, Harish Doddi, David Talby
# 54                         Nat Torkington
# 55                 Ihab Ilyas, Ben Lorica
# 56                         Nat Torkington
# 57                          Adam Tornhill
# 58             Rebecca Parsons, Neal Ford
# 59                       Michael Feathers
#
#                                         author_detail  \
# 0                          {'name': 'Nat Torkington'}
# 1                          {'name': 'Nat Torkington'}
# 2                              {'name': 'Adam Jacob'}
# 3                                                 NaN
# 4                          {'name': 'Roger Magoulas'}
# 5                             {'name': 'VM Brasseur'}
# 6                          {'name': 'Pete Skomoroch'}
# 7                              {'name': 'Ben Lorica'}
# 8                          {'name': 'Nat Torkington'}
# 9                  {'name': 'Pedro Cruz, Brad Topol'}
# 10                             {'name': 'Mac Slocum'}
# 11                           {'name': 'Tiffani Bell'}
# 12                             {'name': 'Arun Gupta'}
# 13                           {'name': 'Kay Williams'}
# 14                        {'name': 'Alison McCauley'}
# 15                         {'name': 'Nat Torkington'}
# 16                         {'name': 'Nat Torkington'}
# 17  {'name': 'Ben Lorica, Harish Doddi, David Talby'}
# 18                         {'name': 'Nat Torkington'}
# 19                         {'name': 'Nat Torkington'}
# 20                         {'name': 'Nat Torkington'}
# 21                         {'name': 'Nat Torkington'}
# 22                         {'name': 'Nat Torkington'}
# 23                          {'name': 'Mike Loukides'}
# 24                              {'name': 'Jenn Webb'}
# 25                            {'name': 'Pete Warden'}
# 26                             {'name': 'Tim Kraska'}
# 27                       {'name': 'Abigail Hing Wen'}
# 28                             {'name': 'Haoyuan Li'}
# 29                            {'name': 'Mikio Braun'}
# 30                            {'name': 'Maria Zhang'}
# 31                             {'name': 'Ion Stoica'}
# 32                          {'name': 'Michael James'}
# 33                         {'name': 'Nat Torkington'}
# 34                         {'name': 'Nat Torkington'}
# 35                         {'name': 'Nat Torkington'}
# 36                              {'name': 'Jenn Webb'}
# 37                                                NaN
# 38                         {'name': 'Nat Torkington'}
# 39                         {'name': 'Nat Torkington'}
# 40                         {'name': 'Nat Torkington'}
# 41                             {'name': 'Ben Lorica'}
# 42                         {'name': 'Nat Torkington'}
# 43                             {'name': 'Ben Lorica'}
# 44                         {'name': 'Nat Torkington'}
# 45                         {'name': 'Nat Torkington'}
# 46                             {'name': 'Ben Lorica'}
# 47                         {'name': 'Nat Torkington'}
# 48                         {'name': 'Nat Torkington'}
# 49                         {'name': 'Nat Torkington'}
# 50                         {'name': 'Nat Torkington'}
# 51                             {'name': 'Ben Lorica'}
# 52                         {'name': 'Nat Torkington'}
# 53  {'name': 'Ben Lorica, Harish Doddi, David Talby'}
# 54                         {'name': 'Nat Torkington'}
# 55                 {'name': 'Ihab Ilyas, Ben Lorica'}
# 56                         {'name': 'Nat Torkington'}
# 57                          {'name': 'Adam Tornhill'}
# 58             {'name': 'Rebecca Parsons, Neal Ford'}
# 59                       {'name': 'Michael Feathers'}
#
#                                               authors  \
# 0                        [{'name': 'Nat Torkington'}]
# 1                        [{'name': 'Nat Torkington'}]
# 2                            [{'name': 'Adam Jacob'}]
# 3                                                 NaN
# 4                        [{'name': 'Roger Magoulas'}]
# 5                           [{'name': 'VM Brasseur'}]
# 6                        [{'name': 'Pete Skomoroch'}]
# 7                            [{'name': 'Ben Lorica'}]
# 8                        [{'name': 'Nat Torkington'}]
# 9                [{'name': 'Pedro Cruz, Brad Topol'}]
# 10                           [{'name': 'Mac Slocum'}]
# 11                         [{'name': 'Tiffani Bell'}]
# 12                           [{'name': 'Arun Gupta'}]
# 13                         [{'name': 'Kay Williams'}]
# 14                      [{'name': 'Alison McCauley'}]
# 15                       [{'name': 'Nat Torkington'}]
# 16                       [{'name': 'Nat Torkington'}]
# 17  [{'name': 'Ben Lorica, Harish Doddi, David Tal...
# 18                       [{'name': 'Nat Torkington'}]
# 19                       [{'name': 'Nat Torkington'}]
# 20                       [{'name': 'Nat Torkington'}]
# 21                       [{'name': 'Nat Torkington'}]
# 22                       [{'name': 'Nat Torkington'}]
# 23                        [{'name': 'Mike Loukides'}]
# 24                            [{'name': 'Jenn Webb'}]
# 25                          [{'name': 'Pete Warden'}]
# 26                           [{'name': 'Tim Kraska'}]
# 27                     [{'name': 'Abigail Hing Wen'}]
# 28                           [{'name': 'Haoyuan Li'}]
# 29                          [{'name': 'Mikio Braun'}]
# 30                          [{'name': 'Maria Zhang'}]
# 31                           [{'name': 'Ion Stoica'}]
# 32                        [{'name': 'Michael James'}]
# 33                       [{'name': 'Nat Torkington'}]
# 34                       [{'name': 'Nat Torkington'}]
# 35                       [{'name': 'Nat Torkington'}]
# 36                            [{'name': 'Jenn Webb'}]
# 37                                                NaN
# 38                       [{'name': 'Nat Torkington'}]
# 39                       [{'name': 'Nat Torkington'}]
# 40                       [{'name': 'Nat Torkington'}]
# 41                           [{'name': 'Ben Lorica'}]
# 42                       [{'name': 'Nat Torkington'}]
# 43                           [{'name': 'Ben Lorica'}]
# 44                       [{'name': 'Nat Torkington'}]
# 45                       [{'name': 'Nat Torkington'}]
# 46                           [{'name': 'Ben Lorica'}]
# 47                       [{'name': 'Nat Torkington'}]
# 48                       [{'name': 'Nat Torkington'}]
# 49                       [{'name': 'Nat Torkington'}]
# 50                       [{'name': 'Nat Torkington'}]
# 51                           [{'name': 'Ben Lorica'}]
# 52                       [{'name': 'Nat Torkington'}]
# 53  [{'name': 'Ben Lorica, Harish Doddi, David Tal...
# 54                       [{'name': 'Nat Torkington'}]
# 55               [{'name': 'Ihab Ilyas, Ben Lorica'}]
# 56                       [{'name': 'Nat Torkington'}]
# 57                        [{'name': 'Adam Tornhill'}]
# 58           [{'name': 'Rebecca Parsons, Neal Ford'}]
# 59                     [{'name': 'Michael Feathers'}]
#
#                                               content  \
# 0   [{'type': 'text/html', 'language': None, 'base...
# 1   [{'type': 'text/html', 'language': None, 'base...
# 2   [{'type': 'text/html', 'language': None, 'base...
# 3   [{'type': 'text/html', 'language': None, 'base...
# 4   [{'type': 'text/html', 'language': None, 'base...
# 5   [{'type': 'text/html', 'language': None, 'base...
# 6   [{'type': 'text/html', 'language': None, 'base...
# 7   [{'type': 'text/html', 'language': None, 'base...
# 8   [{'type': 'text/html', 'language': None, 'base...
# 9   [{'type': 'text/html', 'language': None, 'base...
# 10  [{'type': 'text/html', 'language': None, 'base...
# 11  [{'type': 'text/html', 'language': None, 'base...
# 12  [{'type': 'text/html', 'language': None, 'base...
# 13  [{'type': 'text/html', 'language': None, 'base...
# 14  [{'type': 'text/html', 'language': None, 'base...
# 15  [{'type': 'text/html', 'language': None, 'base...
# 16  [{'type': 'text/html', 'language': None, 'base...
# 17  [{'type': 'text/html', 'language': None, 'base...
# 18  [{'type': 'text/html', 'language': None, 'base...
# 19  [{'type': 'text/html', 'language': None, 'base...
# 20  [{'type': 'text/html', 'language': None, 'base...
# 21  [{'type': 'text/html', 'language': None, 'base...
# 22  [{'type': 'text/html', 'language': None, 'base...
# 23  [{'type': 'text/html', 'language': None, 'base...
# 24  [{'type': 'text/html', 'language': None, 'base...
# 25  [{'type': 'text/html', 'language': None, 'base...
# 26  [{'type': 'text/html', 'language': None, 'base...
# 27  [{'type': 'text/html', 'language': None, 'base...
# 28  [{'type': 'text/html', 'language': None, 'base...
# 29  [{'type': 'text/html', 'language': None, 'base...
# 30  [{'type': 'text/html', 'language': None, 'base...
# 31  [{'type': 'text/html', 'language': None, 'base...
# 32  [{'type': 'text/html', 'language': None, 'base...
# 33  [{'type': 'text/html', 'language': None, 'base...
# 34  [{'type': 'text/html', 'language': None, 'base...
# 35  [{'type': 'text/html', 'language': None, 'base...
# 36  [{'type': 'text/html', 'language': None, 'base...
# 37  [{'type': 'text/html', 'language': None, 'base...
# 38  [{'type': 'text/html', 'language': None, 'base...
# 39  [{'type': 'text/html', 'language': None, 'base...
# 40  [{'type': 'text/html', 'language': None, 'base...
# 41  [{'type': 'text/html', 'language': None, 'base...
# 42  [{'type': 'text/html', 'language': None, 'base...
# 43  [{'type': 'text/html', 'language': None, 'base...
# 44  [{'type': 'text/html', 'language': None, 'base...
# 45  [{'type': 'text/html', 'language': None, 'base...
# 46  [{'type': 'text/html', 'language': None, 'base...
# 47  [{'type': 'text/html', 'language': None, 'base...
# 48  [{'type': 'text/html', 'language': None, 'base...
# 49  [{'type': 'text/html', 'language': None, 'base...
# 50  [{'type': 'text/html', 'language': None, 'base...
# 51  [{'type': 'text/html', 'language': None, 'base...
# 52  [{'type': 'text/html', 'language': None, 'base...
# 53  [{'type': 'text/html', 'language': None, 'base...
# 54  [{'type': 'text/html', 'language': None, 'base...
# 55  [{'type': 'text/html', 'language': None, 'base...
# 56  [{'type': 'text/html', 'language': None, 'base...
# 57  [{'type': 'text/html', 'language': None, 'base...
# 58  [{'type': 'text/html', 'language': None, 'base...
# 59  [{'type': 'text/html', 'language': None, 'base...
#
#                                   feedburner_origlink  guidislink  \
# 0   https://www.oreilly.com/ideas/four-short-links...        True
# 1   https://www.oreilly.com/ideas/four-short-links...        True
# 2   https://www.oreilly.com/ideas/the-war-for-the-...        True
# 3   https://www.oreilly.com/ideas/oreilly-open-sou...        True
# 4   https://www.oreilly.com/ideas/oreilly-radar-op...        True
# 5   https://www.oreilly.com/ideas/ask-not-what-bra...        True
# 6     https://www.oreilly.com/ideas/managing-machines        True
# 7   https://www.oreilly.com/ideas/acquiring-and-sh...        True
# 8   https://www.oreilly.com/ideas/four-short-links...        True
# 9   https://www.oreilly.com/ideas/the-role-of-open...        True
# 10  https://www.oreilly.com/ideas/highlights-from-...        True
# 11  https://www.oreilly.com/ideas/better-living-th...        True
# 12  https://www.oreilly.com/ideas/why-amazon-cares...        True
# 13  https://www.oreilly.com/ideas/built-to-last-bu...        True
# 14  https://www.oreilly.com/ideas/the-next-age-of-...        True
# 15  https://www.oreilly.com/ideas/four-short-links...        True
# 16  https://www.oreilly.com/ideas/four-short-links...        True
# 17  https://www.oreilly.com/ideas/managing-machine...        True
# 18  https://www.oreilly.com/ideas/four-short-links...        True
# 19  https://www.oreilly.com/ideas/four-short-links...        True
# 20  https://www.oreilly.com/ideas/four-short-links...        True
# 21  https://www.oreilly.com/ideas/four-short-links...        True
# 22  https://www.oreilly.com/ideas/four-short-links...        True
# 23  https://www.oreilly.com/ideas/the-circle-of-fa...        True
# 24  https://www.oreilly.com/ideas/highlights-from-...        True
# 25  https://www.oreilly.com/ideas/the-future-of-ma...        True
# 26  https://www.oreilly.com/ideas/toward-learned-a...        True
# 27  https://www.oreilly.com/ideas/top-ai-breakthro...        True
# 28  https://www.oreilly.com/ideas/data-orchestrati...        True
# 29        https://www.oreilly.com/ideas/ai-and-retail        True
# 30  https://www.oreilly.com/ideas/the-future-of-hi...        True
# 31  https://www.oreilly.com/ideas/ai-and-systems-a...        True
# 32  https://www.oreilly.com/ideas/designing-comput...        True
# 33  https://www.oreilly.com/ideas/four-short-links...        True
# 34  https://www.oreilly.com/ideas/four-short-links...        True
# 35  https://www.oreilly.com/ideas/four-short-links...        True
# 36  https://www.oreilly.com/ideas/tools-for-machin...        True
# 37  https://www.oreilly.com/ideas/new-live-online-...        True
# 38  https://www.oreilly.com/ideas/four-short-links...        True
# 39  https://www.oreilly.com/ideas/four-short-links...        True
# 40  https://www.oreilly.com/ideas/four-short-links...        True
# 41  https://www.oreilly.com/ideas/riselabs-autopan...        True
# 42  https://www.oreilly.com/ideas/four-short-links...        True
# 43  https://www.oreilly.com/ideas/one-simple-chart...        True
# 44  https://www.oreilly.com/ideas/four-short-links...        True
# 45  https://www.oreilly.com/ideas/four-short-links...        True
# 46  https://www.oreilly.com/ideas/ai-and-machine-l...        True
# 47  https://www.oreilly.com/ideas/four-short-links...        True
# 48  https://www.oreilly.com/ideas/four-short-links...        True
# 49  https://www.oreilly.com/ideas/four-short-links...        True
# 50  https://www.oreilly.com/ideas/four-short-links...        True
# 51  https://www.oreilly.com/ideas/enabling-end-to-...        True
# 52  https://www.oreilly.com/ideas/four-short-links...        True
# 53  https://www.oreilly.com/ideas/what-are-model-g...        True
# 54  https://www.oreilly.com/ideas/four-short-links...        True
# 55  https://www.oreilly.com/ideas/the-quest-for-hi...        True
# 56  https://www.oreilly.com/ideas/four-short-links...        True
# 57  https://www.oreilly.com/ideas/prioritizing-tec...        True
# 58  https://www.oreilly.com/ideas/from-the-trenche...        True
# 59     https://www.oreilly.com/ideas/choices-of-scale        True
#
#                                                    id  \
# 0   tag:www.oreilly.com,2019-07-22:/ideas/four-sho...
# 1   tag:www.oreilly.com,2019-07-19:/ideas/four-sho...
# 2   tag:www.oreilly.com,2019-07-18:/ideas/the-war-...
# 3   tag:www.oreilly.com,2019-07-18:/ideas/oreilly-...
# 4   tag:www.oreilly.com,2019-07-18:/ideas/oreilly-...
# 5   tag:www.oreilly.com,2019-07-18:/ideas/ask-not-...
# 6   tag:www.oreilly.com,2019-07-18:/ideas/managing...
# 7   tag:www.oreilly.com,2019-07-18:/ideas/acquirin...
# 8   tag:www.oreilly.com,2019-07-18:/ideas/four-sho...
# 9   tag:www.oreilly.com,2019-07-17:/ideas/the-role...
# 10  tag:www.oreilly.com,2019-07-17:/ideas/highligh...
# 11  tag:www.oreilly.com,2019-07-17:/ideas/better-l...
# 12  tag:www.oreilly.com,2019-07-17:/ideas/why-amaz...
# 13  tag:www.oreilly.com,2019-07-17:/ideas/built-to...
# 14  tag:www.oreilly.com,2019-07-17:/ideas/the-next...
# 15  tag:www.oreilly.com,2019-07-17:/ideas/four-sho...
# 16  tag:www.oreilly.com,2019-07-16:/ideas/four-sho...
# 17  tag:www.oreilly.com,2019-07-15:/ideas/managing...
# 18  tag:www.oreilly.com,2019-07-15:/ideas/four-sho...
# 19  tag:www.oreilly.com,2019-07-12:/ideas/four-sho...
# 20  tag:www.oreilly.com,2019-07-11:/ideas/four-sho...
# 21  tag:www.oreilly.com,2019-07-10:/ideas/four-sho...
# 22  tag:www.oreilly.com,2019-07-09:/ideas/four-sho...
# 23  tag:www.oreilly.com,2019-07-09:/ideas/the-circ...
# 24  tag:www.oreilly.com,2019-07-08:/ideas/highligh...
# 25  tag:www.oreilly.com,2019-07-08:/ideas/the-futu...
# 26  tag:www.oreilly.com,2019-07-08:/ideas/toward-l...
# 27  tag:www.oreilly.com,2019-07-08:/ideas/top-ai-b...
# 28  tag:www.oreilly.com,2019-07-08:/ideas/data-orc...
# 29  tag:www.oreilly.com,2019-07-08:/ideas/ai-and-r...
# 30  tag:www.oreilly.com,2019-07-08:/ideas/the-futu...
# 31  tag:www.oreilly.com,2019-07-08:/ideas/ai-and-s...
# 32  tag:www.oreilly.com,2019-07-08:/ideas/designin...
# 33  tag:www.oreilly.com,2019-07-08:/ideas/four-sho...
# 34  tag:www.oreilly.com,2019-07-05:/ideas/four-sho...
# 35  tag:www.oreilly.com,2019-07-04:/ideas/four-sho...
# 36  tag:www.oreilly.com,2019-07-03:/ideas/tools-fo...
# 37  tag:www.oreilly.com,2019-07-03:/ideas/new-live...
# 38  tag:www.oreilly.com,2019-07-03:/ideas/four-sho...
# 39  tag:www.oreilly.com,2019-07-02:/ideas/four-sho...
# 40  tag:www.oreilly.com,2019-07-01:/ideas/four-sho...
# 41  tag:www.oreilly.com,2019-07-01:/ideas/riselabs...
# 42  tag:www.oreilly.com,2019-06-28:/ideas/four-sho...
# 43  tag:www.oreilly.com,2019-06-27:/ideas/one-simp...
# 44  tag:www.oreilly.com,2019-06-27:/ideas/four-sho...
# 45  tag:www.oreilly.com,2019-06-26:/ideas/four-sho...
# 46  tag:www.oreilly.com,2019-06-26:/ideas/ai-and-m...
# 47  tag:www.oreilly.com,2019-06-25:/ideas/four-sho...
# 48  tag:www.oreilly.com,2019-06-24:/ideas/four-sho...
# 49  tag:www.oreilly.com,2019-06-21:/ideas/four-sho...
# 50  tag:www.oreilly.com,2019-06-20:/ideas/four-sho...
# 51  tag:www.oreilly.com,2019-06-20:/ideas/enabling...
# 52  tag:www.oreilly.com,2019-06-19:/ideas/four-sho...
# 53  tag:www.oreilly.com,2019-06-19:/ideas/what-are...
# 54  tag:www.oreilly.com,2019-06-18:/ideas/four-sho...
# 55  tag:www.oreilly.com,2019-06-18:/ideas/the-ques...
# 56  tag:www.oreilly.com,2019-06-17:/ideas/four-sho...
# 57  tag:www.oreilly.com,2019-06-14:/ideas/prioriti...
# 58  tag:www.oreilly.com,2019-06-14:/ideas/from-the...
# 59  tag:www.oreilly.com,2019-06-14:/ideas/choices-...
#
#                                                  link  \
# 0   http://feedproxy.google.com/~r/oreilly/radar/a...
# 1   http://feedproxy.google.com/~r/oreilly/radar/a...
# 2   http://feedproxy.google.com/~r/oreilly/radar/a...
# 3   http://feedproxy.google.com/~r/oreilly/radar/a...
# 4   http://feedproxy.google.com/~r/oreilly/radar/a...
# 5   http://feedproxy.google.com/~r/oreilly/radar/a...
# 6   http://feedproxy.google.com/~r/oreilly/radar/a...
# 7   http://feedproxy.google.com/~r/oreilly/radar/a...
# 8   http://feedproxy.google.com/~r/oreilly/radar/a...
# 9   http://feedproxy.google.com/~r/oreilly/radar/a...
# 10  http://feedproxy.google.com/~r/oreilly/radar/a...
# 11  http://feedproxy.google.com/~r/oreilly/radar/a...
# 12  http://feedproxy.google.com/~r/oreilly/radar/a...
# 13  http://feedproxy.google.com/~r/oreilly/radar/a...
# 14  http://feedproxy.google.com/~r/oreilly/radar/a...
# 15  http://feedproxy.google.com/~r/oreilly/radar/a...
# 16  http://feedproxy.google.com/~r/oreilly/radar/a...
# 17  http://feedproxy.google.com/~r/oreilly/radar/a...
# 18  http://feedproxy.google.com/~r/oreilly/radar/a...
# 19  http://feedproxy.google.com/~r/oreilly/radar/a...
# 20  http://feedproxy.google.com/~r/oreilly/radar/a...
# 21  http://feedproxy.google.com/~r/oreilly/radar/a...
# 22  http://feedproxy.google.com/~r/oreilly/radar/a...
# 23  http://feedproxy.google.com/~r/oreilly/radar/a...
# 24  http://feedproxy.google.com/~r/oreilly/radar/a...
# 25  http://feedproxy.google.com/~r/oreilly/radar/a...
# 26  http://feedproxy.google.com/~r/oreilly/radar/a...
# 27  http://feedproxy.google.com/~r/oreilly/radar/a...
# 28  http://feedproxy.google.com/~r/oreilly/radar/a...
# 29  http://feedproxy.google.com/~r/oreilly/radar/a...
# 30  http://feedproxy.google.com/~r/oreilly/radar/a...
# 31  http://feedproxy.google.com/~r/oreilly/radar/a...
# 32  http://feedproxy.google.com/~r/oreilly/radar/a...
# 33  http://feedproxy.google.com/~r/oreilly/radar/a...
# 34  http://feedproxy.google.com/~r/oreilly/radar/a...
# 35  http://feedproxy.google.com/~r/oreilly/radar/a...
# 36  http://feedproxy.google.com/~r/oreilly/radar/a...
# 37  http://feedproxy.google.com/~r/oreilly/radar/a...
# 38  http://feedproxy.google.com/~r/oreilly/radar/a...
# 39  http://feedproxy.google.com/~r/oreilly/radar/a...
# 40  http://feedproxy.google.com/~r/oreilly/radar/a...
# 41  http://feedproxy.google.com/~r/oreilly/radar/a...
# 42  http://feedproxy.google.com/~r/oreilly/radar/a...
# 43  http://feedproxy.google.com/~r/oreilly/radar/a...
# 44  http://feedproxy.google.com/~r/oreilly/radar/a...
# 45  http://feedproxy.google.com/~r/oreilly/radar/a...
# 46  http://feedproxy.google.com/~r/oreilly/radar/a...
# 47  http://feedproxy.google.com/~r/oreilly/radar/a...
# 48  http://feedproxy.google.com/~r/oreilly/radar/a...
# 49  http://feedproxy.google.com/~r/oreilly/radar/a...
# 50  http://feedproxy.google.com/~r/oreilly/radar/a...
# 51  http://feedproxy.google.com/~r/oreilly/radar/a...
# 52  http://feedproxy.google.com/~r/oreilly/radar/a...
# 53  http://feedproxy.google.com/~r/oreilly/radar/a...
# 54  http://feedproxy.google.com/~r/oreilly/radar/a...
# 55  http://feedproxy.google.com/~r/oreilly/radar/a...
# 56  http://feedproxy.google.com/~r/oreilly/radar/a...
# 57  http://feedproxy.google.com/~r/oreilly/radar/a...
# 58  http://feedproxy.google.com/~r/oreilly/radar/a...
# 59  http://feedproxy.google.com/~r/oreilly/radar/a...
#
#                                                 links  \
# 0   [{'href': 'http://feedproxy.google.com/~r/orei...
# 1   [{'href': 'http://feedproxy.google.com/~r/orei...
# 2   [{'href': 'http://feedproxy.google.com/~r/orei...
# 3   [{'href': 'http://feedproxy.google.com/~r/orei...
# 4   [{'href': 'http://feedproxy.google.com/~r/orei...
# 5   [{'href': 'http://feedproxy.google.com/~r/orei...
# 6   [{'href': 'http://feedproxy.google.com/~r/orei...
# 7   [{'href': 'http://feedproxy.google.com/~r/orei...
# 8   [{'href': 'http://feedproxy.google.com/~r/orei...
# 9   [{'href': 'http://feedproxy.google.com/~r/orei...
# 10  [{'href': 'http://feedproxy.google.com/~r/orei...
# 11  [{'href': 'http://feedproxy.google.com/~r/orei...
# 12  [{'href': 'http://feedproxy.google.com/~r/orei...
# 13  [{'href': 'http://feedproxy.google.com/~r/orei...
# 14  [{'href': 'http://feedproxy.google.com/~r/orei...
# 15  [{'href': 'http://feedproxy.google.com/~r/orei...
# 16  [{'href': 'http://feedproxy.google.com/~r/orei...
# 17  [{'href': 'http://feedproxy.google.com/~r/orei...
# 18  [{'href': 'http://feedproxy.google.com/~r/orei...
# 19  [{'href': 'http://feedproxy.google.com/~r/orei...
# 20  [{'href': 'http://feedproxy.google.com/~r/orei...
# 21  [{'href': 'http://feedproxy.google.com/~r/orei...
# 22  [{'href': 'http://feedproxy.google.com/~r/orei...
# 23  [{'href': 'http://feedproxy.google.com/~r/orei...
# 24  [{'href': 'http://feedproxy.google.com/~r/orei...
# 25  [{'href': 'http://feedproxy.google.com/~r/orei...
# 26  [{'href': 'http://feedproxy.google.com/~r/orei...
# 27  [{'href': 'http://feedproxy.google.com/~r/orei...
# 28  [{'href': 'http://feedproxy.google.com/~r/orei...
# 29  [{'href': 'http://feedproxy.google.com/~r/orei...
# 30  [{'href': 'http://feedproxy.google.com/~r/orei...
# 31  [{'href': 'http://feedproxy.google.com/~r/orei...
# 32  [{'href': 'http://feedproxy.google.com/~r/orei...
# 33  [{'href': 'http://feedproxy.google.com/~r/orei...
# 34  [{'href': 'http://feedproxy.google.com/~r/orei...
# 35  [{'href': 'http://feedproxy.google.com/~r/orei...
# 36  [{'href': 'http://feedproxy.google.com/~r/orei...
# 37  [{'href': 'http://feedproxy.google.com/~r/orei...
# 38  [{'href': 'http://feedproxy.google.com/~r/orei...
# 39  [{'href': 'http://feedproxy.google.com/~r/orei...
# 40  [{'href': 'http://feedproxy.google.com/~r/orei...
# 41  [{'href': 'http://feedproxy.google.com/~r/orei...
# 42  [{'href': 'http://feedproxy.google.com/~r/orei...
# 43  [{'href': 'http://feedproxy.google.com/~r/orei...
# 44  [{'href': 'http://feedproxy.google.com/~r/orei...
# 45  [{'href': 'http://feedproxy.google.com/~r/orei...
# 46  [{'href': 'http://feedproxy.google.com/~r/orei...
# 47  [{'href': 'http://feedproxy.google.com/~r/orei...
# 48  [{'href': 'http://feedproxy.google.com/~r/orei...
# 49  [{'href': 'http://feedproxy.google.com/~r/orei...
# 50  [{'href': 'http://feedproxy.google.com/~r/orei...
# 51  [{'href': 'http://feedproxy.google.com/~r/orei...
# 52  [{'href': 'http://feedproxy.google.com/~r/orei...
# 53  [{'href': 'http://feedproxy.google.com/~r/orei...
# 54  [{'href': 'http://feedproxy.google.com/~r/orei...
# 55  [{'href': 'http://feedproxy.google.com/~r/orei...
# 56  [{'href': 'http://feedproxy.google.com/~r/orei...
# 57  [{'href': 'http://feedproxy.google.com/~r/orei...
# 58  [{'href': 'http://feedproxy.google.com/~r/orei...
# 59  [{'href': 'http://feedproxy.google.com/~r/orei...
#
#                                               summary  \
# 0   <p><em>Game Source, Procurement Graph, Data Mo...
# 1   <p><em>Journal Mining, API Use, Better Convers...
# 2   <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 3   <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 4   <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 5   <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 6   <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 7   <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 8   <p><em>Weird Algorithms, Open Syllabi, Convers...
# 9   <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 10  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 11  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 12  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 13  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 14  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 15  <p><em>Margaret Hamilton, WeChat Censorship, R...
# 16  <p><em>Quantum TiqTaqToe, Social Media and Dep...
# 17  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 18  <p><em>Climbing Robot, Programming and Program...
# 19  <p><em>Hosting Hate, Releasing, Government Inn...
# 20  <p><em>Museum Copyright, Twitter Apprenticeshi...
# 21  <p><em>Optimizations and Security, 512 Byte Pa...
# 22  <p><em>Future of Work, GRANDstack, Hilarious L...
# 23  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 24  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 25  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 26  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 27  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 28  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 29  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 30  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 31  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 32  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 33  <p><em>Algorithmic Governance, DevOps Assessme...
# 34  <p><em>Online Not All Bad, Emotional Space, Te...
# 35  <p><em>Debugging AI, Serverless Foundations, Y...
# 36  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 37  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 38  <p><em>Models, More Models, Robots.txt, and Ev...
# 39  <p><em>Lock Convoys, AI Hardware, Lambda Obser...
# 40  <p><em>General-Purpose Probabilistic Programmi...
# 41  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 42  <p><em>Heartbeat Identity, Seam Carving, Q&A F...
# 43  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 44  <p><em>Security Mnemonics, Evidence Might Work...
# 45  <p><em>Ethics and OKRs, Rewriting Binaries, Di...
# 46  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 47  <p><em>Analog Deep Learning, Low-Trust Interne...
# 48  <p><em>Wacky Timestamps, Computers and Spies, ...
# 49  <p><em>Private Computation, Robot Framework, 3...
# 50  <p><em>Model Governance, Content Moderators, I...
# 51  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 52  <p><em>Voice2Face, DIY Minivac, Cloud Metrics,...
# 53  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 54  <p><em>JavaScript Spreadsheets, Pessimism, Pri...
# 55  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 56  <p><em>Multiverse Databases, Detecting Photosh...
# 57  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 58  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 59  <p><img src='https://d3ucjech6zwjp8.cloudfront...
#
#                                                 title  \
# 0                      Four short links: 22 July 2019
# 1                      Four short links: 19 July 2019
# 2                 The war for the soul of open source
# 3      O'Reilly Open Source and Frank Willison Awards
# 4   O’Reilly Radar: Open source technology trends—...
# 5                 Ask not what Brands™ can do for you
# 6                                   Managing machines
# 7             Acquiring and sharing high-quality data
# 8                      Four short links: 18 July 2019
# 9   The role of open source in mitigating natural ...
# 10  Highlights from the O'Reilly Open Source Softw...
# 11                     Better living through software
# 12                 Why Amazon cares about open source
# 13  Built to last: Building and growing open sourc...
# 14                    The next age of open innovation
# 15                     Four short links: 17 July 2019
# 16                     Four short links: 16 July 2019
# 17  Managing machine learning in the enterprise: L...
# 18                     Four short links: 15 July 2019
# 19                     Four short links: 12 July 2019
# 20                     Four short links: 11 July 2019
# 21                     Four short links: 10 July 2019
# 22                      Four short links: 9 July 2019
# 23                             The circle of fairness
# 24  Highlights from the O'Reilly Artificial Intell...
# 25             The future of machine learning is tiny
# 26  Toward learned algorithms, data structures, an...
# 27              Top AI breakthroughs you need to know
# 28     Data orchestration for AI, big data, and cloud
# 29                                      AI and retail
# 30  The future of hiring and the talent market wit...
# 31                          AI and systems at RISELab
# 32  Designing computer hardware for artificial int...
# 33                      Four short links: 8 July 2019
# 34                      Four short links: 5 July 2019
# 35                      Four short links: 4 July 2019
# 36             Tools for machine learning development
# 37                   New live online training courses
# 38                      Four short links: 3 July 2019
# 39                      Four short links: 2 July 2019
# 40                      Four short links: 1 July 2019
# 41  RISELab’s AutoPandas hints at automation tech ...
# 42                     Four short links: 28 June 2019
# 43  One simple chart: Who is interested in Spark NLP?
# 44                     Four short links: 27 June 2019
# 45                     Four short links: 26 June 2019
# 46  AI and machine learning will require retrainin...
# 47                     Four short links: 25 June 2019
# 48                     Four short links: 24 June 2019
# 49                     Four short links: 21 June 2019
# 50                     Four short links: 20 June 2019
# 51  Enabling end-to-end machine learning pipelines...
# 52                     Four short links: 19 June 2019
# 53    What are model governance and model operations?
# 54                     Four short links: 18 June 2019
# 55                    The quest for high-quality data
# 56                     Four short links: 17 June 2019
# 57  Prioritizing technical debt as if time and mon...
# 58             From the trenches with Rebecca Parsons
# 59                                   Choices of scale
#
#                                          title_detail               updated  \
# 0   {'type': 'text/plain', 'language': None, 'base...  2019-07-22T14:30:00Z
# 1   {'type': 'text/plain', 'language': None, 'base...  2019-07-19T17:05:00Z
# 2   {'type': 'text/plain', 'language': None, 'base...  2019-07-18T20:00:00Z
# 3   {'type': 'text/plain', 'language': None, 'base...  2019-07-18T20:00:00Z
# 4   {'type': 'text/plain', 'language': None, 'base...  2019-07-18T20:00:00Z
# 5   {'type': 'text/plain', 'language': None, 'base...  2019-07-18T20:00:00Z
# 6   {'type': 'text/plain', 'language': None, 'base...  2019-07-18T20:00:00Z
# 7   {'type': 'text/plain', 'language': None, 'base...  2019-07-18T13:30:00Z
# 8   {'type': 'text/plain', 'language': None, 'base...  2019-07-18T08:00:00Z
# 9   {'type': 'text/plain', 'language': None, 'base...  2019-07-17T20:00:00Z
# 10  {'type': 'text/plain', 'language': None, 'base...  2019-07-17T20:00:00Z
# 11  {'type': 'text/plain', 'language': None, 'base...  2019-07-17T20:00:00Z
# 12  {'type': 'text/plain', 'language': None, 'base...  2019-07-17T20:00:00Z
# 13  {'type': 'text/plain', 'language': None, 'base...  2019-07-17T20:00:00Z
# 14  {'type': 'text/plain', 'language': None, 'base...  2019-07-17T20:00:00Z
# 15  {'type': 'text/plain', 'language': None, 'base...  2019-07-17T08:00:00Z
# 16  {'type': 'text/plain', 'language': None, 'base...  2019-07-16T15:10:00Z
# 17  {'type': 'text/plain', 'language': None, 'base...  2019-07-15T11:00:00Z
# 18  {'type': 'text/plain', 'language': None, 'base...  2019-07-15T08:00:00Z
# 19  {'type': 'text/plain', 'language': None, 'base...  2019-07-12T10:50:00Z
# 20  {'type': 'text/plain', 'language': None, 'base...  2019-07-11T12:10:00Z
# 21  {'type': 'text/plain', 'language': None, 'base...  2019-07-10T12:45:00Z
# 22  {'type': 'text/plain', 'language': None, 'base...  2019-07-09T11:40:00Z
# 23  {'type': 'text/plain', 'language': None, 'base...  2019-07-09T11:00:00Z
# 24  {'type': 'text/plain', 'language': None, 'base...  2019-07-08T15:51:00Z
# 25  {'type': 'text/plain', 'language': None, 'base...  2019-07-08T15:50:00Z
# 26  {'type': 'text/plain', 'language': None, 'base...  2019-07-08T15:50:00Z
# 27  {'type': 'text/plain', 'language': None, 'base...  2019-07-08T15:50:00Z
# 28  {'type': 'text/plain', 'language': None, 'base...  2019-07-08T15:50:00Z
# 29  {'type': 'text/plain', 'language': None, 'base...  2019-07-08T15:50:00Z
# 30  {'type': 'text/plain', 'language': None, 'base...  2019-07-08T15:50:00Z
# 31  {'type': 'text/plain', 'language': None, 'base...  2019-07-08T15:50:00Z
# 32  {'type': 'text/plain', 'language': None, 'base...  2019-07-08T15:50:00Z
# 33  {'type': 'text/plain', 'language': None, 'base...  2019-07-08T10:50:00Z
# 34  {'type': 'text/plain', 'language': None, 'base...  2019-07-05T13:10:00Z
# 35  {'type': 'text/plain', 'language': None, 'base...  2019-07-04T13:50:00Z
# 36  {'type': 'text/plain', 'language': None, 'base...  2019-07-03T13:35:00Z
# 37  {'type': 'text/plain', 'language': None, 'base...  2019-07-03T11:20:00Z
# 38  {'type': 'text/plain', 'language': None, 'base...  2019-07-03T11:00:00Z
# 39  {'type': 'text/plain', 'language': None, 'base...  2019-07-02T12:00:00Z
# 40  {'type': 'text/plain', 'language': None, 'base...  2019-07-01T12:30:00Z
# 41  {'type': 'text/plain', 'language': None, 'base...  2019-07-01T11:00:00Z
# 42  {'type': 'text/plain', 'language': None, 'base...  2019-06-28T10:40:00Z
# 43  {'type': 'text/plain', 'language': None, 'base...  2019-06-27T11:10:00Z
# 44  {'type': 'text/plain', 'language': None, 'base...  2019-06-27T10:55:00Z
# 45  {'type': 'text/plain', 'language': None, 'base...  2019-06-26T11:15:00Z
# 46  {'type': 'text/plain', 'language': None, 'base...  2019-06-26T11:00:00Z
# 47  {'type': 'text/plain', 'language': None, 'base...  2019-06-25T10:50:00Z
# 48  {'type': 'text/plain', 'language': None, 'base...  2019-06-24T10:45:00Z
# 49  {'type': 'text/plain', 'language': None, 'base...  2019-06-21T10:45:00Z
# 50  {'type': 'text/plain', 'language': None, 'base...  2019-06-20T21:55:00Z
# 51  {'type': 'text/plain', 'language': None, 'base...  2019-06-20T11:50:00Z
# 52  {'type': 'text/plain', 'language': None, 'base...  2019-06-19T11:05:00Z
# 53  {'type': 'text/plain', 'language': None, 'base...  2019-06-19T11:00:00Z
# 54  {'type': 'text/plain', 'language': None, 'base...  2019-06-18T11:50:00Z
# 55  {'type': 'text/plain', 'language': None, 'base...  2019-06-18T11:00:00Z
# 56  {'type': 'text/plain', 'language': None, 'base...  2019-06-17T10:45:00Z
# 57  {'type': 'text/plain', 'language': None, 'base...  2019-06-14T21:30:00Z
# 58  {'type': 'text/plain', 'language': None, 'base...  2019-06-14T21:30:00Z
# 59  {'type': 'text/plain', 'language': None, 'base...  2019-06-14T21:30:00Z
#
#                          updated_parsed
# 0   (2019, 7, 22, 14, 30, 0, 0, 203, 0)
# 1    (2019, 7, 19, 17, 5, 0, 4, 200, 0)
# 2    (2019, 7, 18, 20, 0, 0, 3, 199, 0)
# 3    (2019, 7, 18, 20, 0, 0, 3, 199, 0)
# 4    (2019, 7, 18, 20, 0, 0, 3, 199, 0)
# 5    (2019, 7, 18, 20, 0, 0, 3, 199, 0)
# 6    (2019, 7, 18, 20, 0, 0, 3, 199, 0)
# 7   (2019, 7, 18, 13, 30, 0, 3, 199, 0)
# 8     (2019, 7, 18, 8, 0, 0, 3, 199, 0)
# 9    (2019, 7, 17, 20, 0, 0, 2, 198, 0)
# 10   (2019, 7, 17, 20, 0, 0, 2, 198, 0)
# 11   (2019, 7, 17, 20, 0, 0, 2, 198, 0)
# 12   (2019, 7, 17, 20, 0, 0, 2, 198, 0)
# 13   (2019, 7, 17, 20, 0, 0, 2, 198, 0)
# 14   (2019, 7, 17, 20, 0, 0, 2, 198, 0)
# 15    (2019, 7, 17, 8, 0, 0, 2, 198, 0)
# 16  (2019, 7, 16, 15, 10, 0, 1, 197, 0)
# 17   (2019, 7, 15, 11, 0, 0, 0, 196, 0)
# 18    (2019, 7, 15, 8, 0, 0, 0, 196, 0)
# 19  (2019, 7, 12, 10, 50, 0, 4, 193, 0)
# 20  (2019, 7, 11, 12, 10, 0, 3, 192, 0)
# 21  (2019, 7, 10, 12, 45, 0, 2, 191, 0)
# 22   (2019, 7, 9, 11, 40, 0, 1, 190, 0)
# 23    (2019, 7, 9, 11, 0, 0, 1, 190, 0)
# 24   (2019, 7, 8, 15, 51, 0, 0, 189, 0)
# 25   (2019, 7, 8, 15, 50, 0, 0, 189, 0)
# 26   (2019, 7, 8, 15, 50, 0, 0, 189, 0)
# 27   (2019, 7, 8, 15, 50, 0, 0, 189, 0)
# 28   (2019, 7, 8, 15, 50, 0, 0, 189, 0)
# 29   (2019, 7, 8, 15, 50, 0, 0, 189, 0)
# 30   (2019, 7, 8, 15, 50, 0, 0, 189, 0)
# 31   (2019, 7, 8, 15, 50, 0, 0, 189, 0)
# 32   (2019, 7, 8, 15, 50, 0, 0, 189, 0)
# 33   (2019, 7, 8, 10, 50, 0, 0, 189, 0)
# 34   (2019, 7, 5, 13, 10, 0, 4, 186, 0)
# 35   (2019, 7, 4, 13, 50, 0, 3, 185, 0)
# 36   (2019, 7, 3, 13, 35, 0, 2, 184, 0)
# 37   (2019, 7, 3, 11, 20, 0, 2, 184, 0)
# 38    (2019, 7, 3, 11, 0, 0, 2, 184, 0)
# 39    (2019, 7, 2, 12, 0, 0, 1, 183, 0)
# 40   (2019, 7, 1, 12, 30, 0, 0, 182, 0)
# 41    (2019, 7, 1, 11, 0, 0, 0, 182, 0)
# 42  (2019, 6, 28, 10, 40, 0, 4, 179, 0)
# 43  (2019, 6, 27, 11, 10, 0, 3, 178, 0)
# 44  (2019, 6, 27, 10, 55, 0, 3, 178, 0)
# 45  (2019, 6, 26, 11, 15, 0, 2, 177, 0)
# 46   (2019, 6, 26, 11, 0, 0, 2, 177, 0)
# 47  (2019, 6, 25, 10, 50, 0, 1, 176, 0)
# 48  (2019, 6, 24, 10, 45, 0, 0, 175, 0)
# 49  (2019, 6, 21, 10, 45, 0, 4, 172, 0)
# 50  (2019, 6, 20, 21, 55, 0, 3, 171, 0)
# 51  (2019, 6, 20, 11, 50, 0, 3, 171, 0)
# 52   (2019, 6, 19, 11, 5, 0, 2, 170, 0)
# 53   (2019, 6, 19, 11, 0, 0, 2, 170, 0)
# 54  (2019, 6, 18, 11, 50, 0, 1, 169, 0)
# 55   (2019, 6, 18, 11, 0, 0, 1, 169, 0)
# 56  (2019, 6, 17, 10, 45, 0, 0, 168, 0)
# 57  (2019, 6, 14, 21, 30, 0, 4, 165, 0)
# 58  (2019, 6, 14, 21, 30, 0, 4, 165, 0)
# 59  (2019, 6, 14, 21, 30, 0, 4, 165, 0)

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
series = df.groupby('author').count().sort_values(by='authors',ascending=False)
series
# Out:
#                                        author_detail  authors  content  \
# author
# Nat Torkington                                    26       26       26
# Ben Lorica                                         5        5        5
# Ben Lorica, Harish Doddi, David Talby              2        2        2
# Jenn Webb                                          2        2        2
# Abigail Hing Wen                                   1        1        1
# Michael James                                      1        1        1
# Tim Kraska                                         1        1        1
# Tiffani Bell                                       1        1        1
# Roger Magoulas                                     1        1        1
# Rebecca Parsons, Neal Ford                         1        1        1
# Pete Warden                                        1        1        1
# Pete Skomoroch                                     1        1        1
# Pedro Cruz, Brad Topol                             1        1        1
# Mikio Braun                                        1        1        1
# Mike Loukides                                      1        1        1
# Maria Zhang                                        1        1        1
# Michael Feathers                                   1        1        1
# Adam Jacob                                         1        1        1
# Mac Slocum                                         1        1        1
# Kay Williams                                       1        1        1
# Ion Stoica                                         1        1        1
# Ihab Ilyas, Ben Lorica                             1        1        1
# Haoyuan Li                                         1        1        1
# Arun Gupta                                         1        1        1
# Alison McCauley                                    1        1        1
# Adam Tornhill                                      1        1        1
# VM Brasseur                                        1        1        1
#
#                                        feedburner_origlink  guidislink  id  \
# author
# Nat Torkington                                          26          26  26
# Ben Lorica                                               5           5   5
# Ben Lorica, Harish Doddi, David Talby                    2           2   2
# Jenn Webb                                                2           2   2
# Abigail Hing Wen                                         1           1   1
# Michael James                                            1           1   1
# Tim Kraska                                               1           1   1
# Tiffani Bell                                             1           1   1
# Roger Magoulas                                           1           1   1
# Rebecca Parsons, Neal Ford                               1           1   1
# Pete Warden                                              1           1   1
# Pete Skomoroch                                           1           1   1
# Pedro Cruz, Brad Topol                                   1           1   1
# Mikio Braun                                              1           1   1
# Mike Loukides                                            1           1   1
# Maria Zhang                                              1           1   1
# Michael Feathers                                         1           1   1
# Adam Jacob                                               1           1   1
# Mac Slocum                                               1           1   1
# Kay Williams                                             1           1   1
# Ion Stoica                                               1           1   1
# Ihab Ilyas, Ben Lorica                                   1           1   1
# Haoyuan Li                                               1           1   1
# Arun Gupta                                               1           1   1
# Alison McCauley                                          1           1   1
# Adam Tornhill                                            1           1   1
# VM Brasseur                                              1           1   1
#
#                                        link  links  summary  title  \
# author
# Nat Torkington                           26     26       26     26
# Ben Lorica                                5      5        5      5
# Ben Lorica, Harish Doddi, David Talby     2      2        2      2
# Jenn Webb                                 2      2        2      2
# Abigail Hing Wen                          1      1        1      1
# Michael James                             1      1        1      1
# Tim Kraska                                1      1        1      1
# Tiffani Bell                              1      1        1      1
# Roger Magoulas                            1      1        1      1
# Rebecca Parsons, Neal Ford                1      1        1      1
# Pete Warden                               1      1        1      1
# Pete Skomoroch                            1      1        1      1
# Pedro Cruz, Brad Topol                    1      1        1      1
# Mikio Braun                               1      1        1      1
# Mike Loukides                             1      1        1      1
# Maria Zhang                               1      1        1      1
# Michael Feathers                          1      1        1      1
# Adam Jacob                                1      1        1      1
# Mac Slocum                                1      1        1      1
# Kay Williams                              1      1        1      1
# Ion Stoica                                1      1        1      1
# Ihab Ilyas, Ben Lorica                    1      1        1      1
# Haoyuan Li                                1      1        1      1
# Arun Gupta                                1      1        1      1
# Alison McCauley                           1      1        1      1
# Adam Tornhill                             1      1        1      1
# VM Brasseur                               1      1        1      1
#
#                                        title_detail  updated  updated_parsed
# author
# Nat Torkington                                   26       26              26
# Ben Lorica                                        5        5               5
# Ben Lorica, Harish Doddi, David Talby             2        2               2
# Jenn Webb                                         2        2               2
# Abigail Hing Wen                                  1        1               1
# Michael James                                     1        1               1
# Tim Kraska                                        1        1               1
# Tiffani Bell                                      1        1               1
# Roger Magoulas                                    1        1               1
# Rebecca Parsons, Neal Ford                        1        1               1
# Pete Warden                                       1        1               1
# Pete Skomoroch                                    1        1               1
# Pedro Cruz, Brad Topol                            1        1               1
# Mikio Braun                                       1        1               1
# Mike Loukides                                     1        1               1
# Maria Zhang                                       1        1               1
# Michael Feathers                                  1        1               1
# Adam Jacob                                        1        1               1
# Mac Slocum                                        1        1               1
# Kay Williams                                      1        1               1
# Ion Stoica                                        1        1               1
# Ihab Ilyas, Ben Lorica                            1        1               1
# Haoyuan Li                                        1        1               1
# Arun Gupta                                        1        1               1
# Alison McCauley                                   1        1               1
# Adam Tornhill                                     1        1               1
# VM Brasseur                                       1        1               1

# %%
#Methode du cours
authors = df.groupby('author', as_index=False).agg({'title':'count'})
authors.columns = ['author', 'entries']
authors.sort_values('entries', ascending=False)
# Out:
#                                    author  entries
# 18                         Nat Torkington       26
# 5                              Ben Lorica        5
# 6   Ben Lorica, Harish Doddi, David Talby        2
# 10                              Jenn Webb        2
# 0                        Abigail Hing Wen        1
# 15                          Michael James        1
# 25                             Tim Kraska        1
# 24                           Tiffani Bell        1
# 23                         Roger Magoulas        1
# 22             Rebecca Parsons, Neal Ford        1
# 21                            Pete Warden        1
# 20                         Pete Skomoroch        1
# 19                 Pedro Cruz, Brad Topol        1
# 17                            Mikio Braun        1
# 16                          Mike Loukides        1
# 13                            Maria Zhang        1
# 14                       Michael Feathers        1
# 1                              Adam Jacob        1
# 12                             Mac Slocum        1
# 11                           Kay Williams        1
# 9                              Ion Stoica        1
# 8                  Ihab Ilyas, Ben Lorica        1
# 7                              Haoyuan Li        1
# 4                              Arun Gupta        1
# 3                         Alison McCauley        1
# 2                           Adam Tornhill        1
# 26                            VM Brasseur        1

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df['title_length'] = df['title'].apply(len)
df[['title', 'author', 'title_length']].sort_values('title_length', ascending=False).head()
# Out:
#                                                 title  \
# 41  RISELab’s AutoPandas hints at automation tech ...
# 17  Managing machine learning in the enterprise: L...
# 24  Highlights from the O'Reilly Artificial Intell...
# 10  Highlights from the O'Reilly Open Source Softw...
# 51  Enabling end-to-end machine learning pipelines...
#
#                                    author  title_length
# 41                             Ben Lorica            97
# 17  Ben Lorica, Harish Doddi, David Talby            81
# 24                              Jenn Webb            79
# 10                             Mac Slocum            77
# 51                             Ben Lorica            73

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
machine_learning = df.loc[(df['summary'].str.contains('machine learning.')==True)]
machine_learning

ml=[]
for summa in df['summary']:
    if 'machine learning.' in summa:
        ml.append(summa)
ml
# Out:
# ['<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/bydgoszcz_przechodzacy_crop-49dd4046437faa3de84b1dd393c128bc.jpg\'/></p><p><em>A look at how guidelines from regulated industries can help shape your ML strategy.</em></p><p>As companies use machine learning (ML) and AI technologies across a broader suite of products and services, it’s clear that new tools, best practices, and new organizational structures will be needed. In recent posts, we described requisite <a href="https://www.oreilly.com/ideas/becoming-a-machine-learning-company-means-investing-in-foundational-technologies">foundational technologies</a> needed to sustain machine learning practices within organizations, and <a href="https://www.oreilly.com/ideas/what-are-model-governance-and-model-operations">specialized tools</a> for model development, model governance, and model operations/testing/monitoring.</p>\r\n\r\n\r\n\r\n<p>What cultural and organizational changes will be needed to accommodate the rise of machine and learning and AI? In this post, we\'ll address this question through the lens of one highly regulated industry: financial services. Financial services firms have a rich tradition of being early adopters of many new technologies, and AI is no exception:</p>\r\n\r\n<figure class="center" id="id-6YOix"><img alt="Stage of adoption of AI technologies" src="https://d3ansictanv2wj.cloudfront.net/Figure1-4498eaf55b7905f15ae962b3d63d54ae.png"><figcaption><span class="label">Figure 1. </span><a href="https://www.oreilly.com/data/free/ai-adoption-in-the-enterprise.csp">Stage of adoption of AI technologies</a> (by industry). Image by Ben Lorica.</figcaption></figure>\r\n\r\n\r\n\r\n\r\n\r\n<p>Alongside health care, another heavily regulated sector, financial services companies have historically had to build in explainability and transparency to some of their algorithms (e.g., <a href="https://www.debt.org/credit/your-consumer-rights/fair-credit-reporting-act/">credit scores</a>). In our experience, many of the most popular conference talks on model explainability and interpretability are those given by speakers from finance.</p>\r\n\r\n\r\n\r\n<figure class="center" id="id-RlWiz"><img alt="AI projects in financial services and health care" src="https://d3ansictanv2wj.cloudfront.net/Figure2-d71740e0aef3aa8728d3fd2e0048119c.png"><figcaption><span class="label">Figure 2. </span><a href="https://www.oreilly.com/data/free/ai-adoption-in-the-enterprise.csp">AI projects in financial services and health care</a>. Image by Ben Lorica.</figcaption></figure>\r\n\r\n\r\n\r\n\r\n\r\n<p>After the 2008 financial crisis, the Federal Reserve issued a new set of guidelines governing models—<a href="https://www.federalreserve.gov/supervisionreg/srletters/sr1107.htm">SR 11-7</a>: <em>Guidance on Model Risk Management</em>. The goal of SR 11-7 was to broaden a set of earlier guidelines which focused mainly on model validation. While there aren’t any surprising things in SR 11-7, it pulls together important considerations that arise once an organization starts using models to power important products and services. In the remainder of this post, we\'ll list the key areas and recommendations covered in SR 11-7, and explain how they are relevant to recent developments in machine learning. (Note that the emphasis of SR 11-7 is on <em>risk management</em>.)</p>\r\n\r\n<h2>Sources of model risk</h2>\r\n\r\n<p>We should clarify that SR 11-7 also covers models that aren’t necessarily based on machine learning: "quantitative method, system, or approach that applies statistical, economic, financial, or mathematical theories, techniques, and assumptions to process input data into quantitative estimates." With this in mind, there are many potential sources of model risk, SR 11-7 highlighted incorrect or inappropriate use of models, and fundamental errors. Machine learning developers are beginning to look at an even broader set of risk factors. In <a href="https://www.oreilly.com/ideas/ ...
#  '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/abstract-texture-floor-cobblestone-wall-pattern-947466-pxhere_crop-e944da930f05b8e09fd1a07fcf8a64e1.jpg\'/></p><p><em>The O\'Reilly Data Show: Ben Lorica chats with Jeff Meyerson of Software Engineering Daily about data engineering, data architecture and infrastructure, and machine learning.</em></p><p>In this week\'s episode of the Data Show, we\'re featuring <a href="https://softwareengineeringdaily.com/2019/04/04/data-with-ben-lorica/">an interview Data Show host Ben Lorica participated in for the Software Engineering Daily Podcast</a>, where he was interviewed by <a href="https://twitter.com/the_prion">Jeff Meyerson</a>. Their conversation mainly centered around data engineering, data architecture and infrastructure, and machine learning (ML).</p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/tools-for-machine-learning-development\'>Tools for machine learning development.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/PMZgT-wOiYA" height="1" width="1" alt=""/>',
#  '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/office-1209640_1920_crop-547bc8922d04c4c2544a083f7f6be057.jpg\'/></p><p><em>To successfully integrate AI and machine learning technologies, companies need to take a more holistic approach toward training their workforce.</em></p><p>In our recent surveys <a href="https://www.oreilly.com/data/free/ai-adoption-in-the-enterprise.csp"><em>AI Adoption in the Enterprise</em></a> and <a href="https://www.oreilly.com/data/free/state-of-machine-learning-adoption-in-the-enterprise.csp"><em>Machine Learning Adoption in the Enterprise</em></a>, we found growing interest in AI technologies among companies across a variety of industries and geographic locations. Our findings align with other surveys and studies—in fact, <a href="https://www.wipo.int/pressroom/en/articles/2019/article_0001.html">a recent study by the World Intellectual Patent Office (WIPO)</a> found that the surge in research in AI and machine learning (ML) has been accompanied by an even stronger growth in AI-related patent applications. Patents are one sign that companies are beginning to take these technologies very seriously.</p>\r\n\r\n<figure class="center" id="id-31Vik"><img alt="" src="https://d3ansictanv2wj.cloudfront.net/image1-6cfd6abd2796b8ad0f049f079bdd48c5.png"><figcaption><span class="label">Figure 1. </span>A <a href="https://www.wipo.int/publications/en/details.jsp?id=4386">2019 WIPO Study</a> shows an over six-fold increase in AI patent publications from 2006 to 2017. Image source: Ben Lorica.</figcaption></figure>\r\n\r\n\r\n<p><a href="https://www.oreilly.com/data/free/ai-adoption-in-the-enterprise.csp">When we asked</a> what held back their adoption of AI technologies, respondents cited a few reasons, including some that pertained to culture, organization, and skills:</p>\r\n<ul>\r\n<li>[23%] Company culture does not yet recognize needs for AI</li>\r\n\r\n<li>[18%] Lack of skilled people / difficulting hiring the required roles</li>\r\n\r\n<li>[17%] Difficulties in identifying appropriate business use cases</li>\r\n</ul>\r\n\r\n\r\n<p>Implementing and incorporating AI and machine learning technologies will require retraining across an organization, not just technical teams. Recall that the rise of big data and data science necessitated a certain amount of retraining across an entire organization: technologists and analysts needed to familiarize themselves with new tools and architectures, but business experts and managers also needed to reorient their workflows to adjust to data-driven processes and data-intensive systems. AI and machine learning will require a similar holistic approach to training. Here are a few reasons why:</p>\r\n\r\n<ul>\r\n\t<li>As noted from our survey, identifying appropriate business use cases remains an ongoing challenge. Domain experts and business owners need to develop an understanding of these technologies in order to be able to highlight areas where they are likely to make an impact within a company.</li>\r\n\t<li>Members of an organization will need to understand—even at a high-level—the current state of AI and ML technologies so they know the strengths and limitations of these new tools. For instance, in the case of <a href="https://en.wikipedia.org/wiki/Robotic_process_automation">robotic process automation (RPA)</a>, it’s really the people closest to tasks (<a href="https://twitter.com/timoreilly/status/1111421767216562176">“bottoms up”</a>) who can best identify areas where it is most suitable.</li>\r\n\t<li>AI and machine learning depend on data (usually labeled training data for machine learning models), and in many instances, a certain amount of domain knowledge will be needed to assemble high-quality data.</li>\r\n\t<li>Machine learning and AI involve end-to-end pipelines, so development/testing/integration will often cut across technical roles and technical teams.</li>\r\n\t<li>AI and machine learning applications and solutions often interact with (or a ...

# %% [markdown]
# ## Global Historical Climatology Network Dataset
# Variables are stored in both rows and columns
# This dataset represents the daily weather records for a weather station (MX17004) in Mexico for five months in 2010.

# %%
import pandas as pd
import numpy as np

# %%
weather = pd.read_csv('../weather-raw.csv', sep=',')
weather.head()
# Out:
#         id  year  month element  d1    d2    d3  d4    d5  d6  ...  d22   d23  \
# 0  MX17004  2010      1    tmax NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 1  MX17004  2010      1    tmin NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 2  MX17004  2010      2    tmax NaN  27.3  24.1 NaN   NaN NaN  ...  NaN  29.9
# 3  MX17004  2010      2    tmin NaN  14.4  14.4 NaN   NaN NaN  ...  NaN  10.7
# 4  MX17004  2010      3    tmax NaN   NaN   NaN NaN  32.1 NaN  ...  NaN   NaN
#
#    d24  d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  14.5  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 35 columns]

# %%
"""for col in weather.columns:
    print(weather[col].value_counts())
#weather.dtypes"""
# Out:
# 'for col in weather.columns:\n    print(weather[col].value_counts())\n#weather.dtypes'

# %%
#on peut supprimer les colonnes Id et Year car c'est la même info qui est contenue à chaque fois. 
#on retient qu'il s'agit de données relevées à la station ayant l'identifiant MX17004 en 2010.
weather=weather.drop(columns=['id', 'year'])
weather.head()
# Out:
#    month element  d1    d2    d3  d4    d5  d6  d7  d8  ...  d22   d23  d24  \
# 0      1    tmax NaN   NaN   NaN NaN   NaN NaN NaN NaN  ...  NaN   NaN  NaN
# 1      1    tmin NaN   NaN   NaN NaN   NaN NaN NaN NaN  ...  NaN   NaN  NaN
# 2      2    tmax NaN  27.3  24.1 NaN   NaN NaN NaN NaN  ...  NaN  29.9  NaN
# 3      2    tmin NaN  14.4  14.4 NaN   NaN NaN NaN NaN  ...  NaN  10.7  NaN
# 4      3    tmax NaN   NaN   NaN NaN  32.1 NaN NaN NaN  ...  NaN   NaN  NaN
#
#    d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  14.5  NaN
# 2  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 33 columns]

# %%
weather=pd.melt(weather,id_vars=['month','element'])
weather.head()
# Out:
#    month element variable  value
# 0      1    tmax       d1    NaN
# 1      1    tmin       d1    NaN
# 2      2    tmax       d1    NaN
# 3      2    tmin       d1    NaN
# 4      3    tmax       d1    NaN

# %%
weather=weather.rename(columns={'value':'temp'})
weather=weather.rename(columns={'variable':'day'})
weather['month_day'] = 'M' +weather['month'].map(str) + '-' + weather['day'].map(str)

# %%
weather
#piv=weather.pivot(index='month_day',columns='element',values='temp')
#piv
# Out:
#      month element  day       temp month_day
# 0        1    tmax   d1  21.921212     M1-d1
# 1        1    tmin   d1  21.921212     M1-d1
# 2        2    tmax   d1  21.921212     M2-d1
# 3        2    tmin   d1  21.921212     M2-d1
# 4        3    tmax   d1  21.921212     M3-d1
# 5        3    tmin   d1  21.921212     M3-d1
# 6        4    tmax   d1  21.921212     M4-d1
# 7        4    tmin   d1  21.921212     M4-d1
# 8        5    tmax   d1  21.921212     M5-d1
# 9        5    tmin   d1  21.921212     M5-d1
# 10       6    tmax   d1  21.921212     M6-d1
# 11       6    tmin   d1  21.921212     M6-d1
# 12       7    tmax   d1  21.921212     M7-d1
# 13       7    tmin   d1  21.921212     M7-d1
# 14       8    tmax   d1  21.921212     M8-d1
# 15       8    tmin   d1  21.921212     M8-d1
# 16      10    tmax   d1  21.921212    M10-d1
# 17      10    tmin   d1  21.921212    M10-d1
# 18      11    tmax   d1  21.921212    M11-d1
# 19      11    tmin   d1  21.921212    M11-d1
# ...

# %%
#piv.fillna(piv.mean(), inplace=True)
piv.fillna(method='bfill', inplace=True)

piv
# Out:
# element         tmax       tmin
# month_day
# M1-d1      29.190909  14.651515
# M1-d10     29.190909  14.651515
# M1-d11     29.190909  14.651515
# M1-d12     29.190909  14.651515
# M1-d13     29.190909  14.651515
# M1-d14     29.190909  14.651515
# M1-d15     29.190909  14.651515
# M1-d16     29.190909  14.651515
# M1-d17     29.190909  14.651515
# M1-d18     29.190909  14.651515
# M1-d19     29.190909  14.651515
# M1-d2      29.190909  14.651515
# M1-d20     29.190909  14.651515
# M1-d21     29.190909  14.651515
# M1-d22     29.190909  14.651515
# M1-d23     29.190909  14.651515
# M1-d24     29.190909  14.651515
# M1-d25     29.190909  14.651515
# M1-d26     29.190909  14.651515
# M1-d27     29.190909  14.651515
# M1-d28     29.190909  14.651515
# M1-d29     29.190909  14.651515
# M1-d3      29.190909  14.651515
# M1-d30     27.800000  14.500000
# M1-d31     29.190909  14.651515
# M1-d4      29.190909  14.651515
# M1-d5      29.190909  14.651515
# M1-d6      29.190909  14.651515
# ...

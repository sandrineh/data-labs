# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(exclude ='object').head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
#your code here- categorical variable
titanic.select_dtypes(include ='object').head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.style.use('classic')
fig = plt.figure(figsize=(12, 6))
print(plt.style.available)
# Out:
# ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-whitegrid', 'classic', '_classic_test', 'fast', 'seaborn-talk', 'seaborn-dark-palette', 'seaborn-bright', 'seaborn-pastel', 'grayscale', 'seaborn-notebook', 'ggplot', 'seaborn-colorblind', 'seaborn-muted', 'seaborn', 'Solarize_Light2', 'seaborn-paper', 'bmh', 'tableau-colorblind10', 'seaborn-white', 'dark_background', 'seaborn-poster', 'seaborn-deep']

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
ax = titanic['Age'].hist()

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
fig, ax=plt.subplots(3,1)
ax[0].hist(titanic['Age'],bins=10,color="dodgerblue")
ax[1].hist(titanic['Age'],bins=20,color="deeppink")
ax[2].hist(titanic['Age'],bins=50,color="gold")
# Out:
# (array([ 22.,  19.,  10.,  11.,  10.,  13.,   8.,   8.,  23.,  26.,  20.,
#          75.,  29.,  93., 109.,  43.,  72.,  68., 111.,  53.,  71.,  47.,
#          35.,  24.,  43.,  26.,  29.,  15.,  35.,  31.,  15.,  26.,   7.,
#          14.,  13.,   5.,   9.,   8.,  11.,   9.,   3.,   2.,   0.,   2.,
#           3.,   0.,   1.,   1.,   0.,   1.]),
#  array([ 0.17  ,  1.7666,  3.3632,  4.9598,  6.5564,  8.153 ,  9.7496,
#         11.3462, 12.9428, 14.5394, 16.136 , 17.7326, 19.3292, 20.9258,
#         22.5224, 24.119 , 25.7156, 27.3122, 28.9088, 30.5054, 32.102 ,
#         33.6986, 35.2952, 36.8918, 38.4884, 40.085 , 41.6816, 43.2782,
#         44.8748, 46.4714, 48.068 , 49.6646, 51.2612, 52.8578, 54.4544,
#         56.051 , 57.6476, 59.2442, 60.8408, 62.4374, 64.034 , 65.6306,
#         67.2272, 68.8238, 70.4204, 72.017 , 73.6136, 75.2102, 76.8068,
#         78.4034, 80.    ]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
#le choix de la taille de classe d'intervalles (bin) permet d'avoir une idée plus claire de la répartition par âge.
#cela distribue de façon plus fine les âges

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.distplot(titanic['Age'], bins=20)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way

gender = titanic['Gender'].value_counts()#titanic.groupby('Gender').count()
gender = pd.DataFrame(gender)

labels = gender.index.tolist()
sizes = [x for x in gender['Gender']]
gender,labels,sizes

explode = (0, 0.1)
fig1, ax1 = plt.subplots()
colors = ['#ff6666', '#ffcc99']#colors
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=False, startangle=90, colors=colors)


ax1.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
# your code here- 2nd way

ax = sns.barplot(x=labels,y=sizes, data=gender)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'male'), Text(0, 0, 'female')]

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here

pclass = titanic['Pclass'].value_counts()
pclass = pd.DataFrame(pclass)

labels = pclass.index.tolist()
sizes = [x for x in pclass['Pclass']]

ax = sns.barplot(x=labels, y=sizes, data=pclass)
ax.set_xticklabels(ax.get_xticklabels())
# Out:
# [Text(0, 0, '1'), Text(0, 0, '2'), Text(0, 0, '3')]

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
#titanic.boxplot(column="Age")
ax = sns.boxplot(x="Age", data=titanic)

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
#l'âge des passagers du titanic se situe entre 20 et 40 ans avec une médiane d'un peu moins de 30 ans.
#la personne la plus agée a 80 ans et la plus jeune est un nouveau né. 
#titanic['Age'].describe()

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
# Import library and dataset
 
# Cut the window in 2 parts
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# Add a graph in each part
sns.boxplot(x="Age", ax=ax_box, data=titanic)
#sns.boxplot(df["sepal_length"], ax=ax_box)
#sns.distplot(df["sepal_length"], ax=ax_hist)
sns.distplot(titanic['Age'], bins=20, ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')
# Out:
# [Text(0.5, 0, '')]

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
#On constate qu'il une variation de distribution dans la classe d'âge 0-5 ans ce que l'on voit moins dans le box-plot.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
titanic.sort_values(by='Fare',ascending=False).head()
# Out:
#       PassengerId  Survived  Pclass  \
# 737           738       1.0       1
# 1234         1235       NaN       1
# 258           259       1.0       1
# 679           680       1.0       1
# 438           439       0.0       1
#
#                                                    Name  Gender   Age  SibSp  \
# 737                              Lesurer, Mr. Gustave J    male  35.0      0
# 1234  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 258                                    Ward, Miss. Anna  female  35.0      0
# 679                  Cardeza, Mr. Thomas Drake Martinez    male  36.0      0
# 438                                   Fortune, Mr. Mark    male  64.0      1
#
#       Parch    Ticket      Fare        Cabin Embarked
# 737       0  PC 17755  512.3292         B101        C
# 1234      1  PC 17755  512.3292  B51 B53 B55        C
# 258       0  PC 17755  512.3292           U0        C
# 679       1  PC 17755  512.3292  B51 B53 B55        C
# ...

# %%
#your code-1st way
sns.scatterplot(x="Age", y="Fare", data=titanic)

# %%
# your code-2nd way
fig,ax=plt.subplots(figsize=(12,6))
ax = sns.barplot(x="Age", y="Fare", data=titanic)

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
# Set up the matplotlib figure
fig, ax = plt.subplots(figsize=(11, 9))
sns.set(style="white")

# Compute the correlation matrix
corr = titanic.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Generate a custom diverging colormap
cmap = sns.diverging_palette(250, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
ax = sns.heatmap(corr, mask=mask, cmap=cmap, annot=True, center=0,square=True, linewidths=.5,cbar_kws={"shrink":.5})

#square => pour obtenir des fornmes carré, cbar=> c'est l'échelle à droite, on peut déterminer sa taille (hauteur)
#linewidths=>pour l'épaisseur de trait entre chaque carré, cmap=>pour déterminer la palette de couleur

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
#the most correlated feature are Parch and SibSP

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
ax = sns.boxplot(x="Pclass", y="Age", data=titanic)
ax.set_xticklabels(ax.get_xticklabels(),rotation=0)
# Out:
# [Text(0, 0, '1'), Text(0, 0, '2'), Text(0, 0, '3')]

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
g = sns.FacetGrid(titanic, col="Gender")
g = g.map(plt.hist, "Age")
